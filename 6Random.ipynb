# %%
import pandas as pd
file_path = 'Meteorite_Landings.csv' 
meteorite_data = pd.read_csv(file_path)

# %%
from Modules.meteorite_classification import classify_meteorites
meteorite_data['classification_group'] = meteorite_data['recclass'].apply(classify_meteorites) #apply the ouput of the module to the data

# %%
from Modules.random import * 
m = display_map_with_search_bar(meteorite_data, 10)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c87c1b9349d10eaeb24adca84b9fe911 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c87c1b9349d10eaeb24adca84b9fe911&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c87c1b9349d10eaeb24adca84b9fe911 = L.map(
#                 &quot;map_c87c1b9349d10eaeb24adca84b9fe911&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0814127f2c8e5cf488e46400cedd73aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0814127f2c8e5cf488e46400cedd73aa.addTo(map_c87c1b9349d10eaeb24adca84b9fe911);
#
#
#             var feature_group_72ea3c1c49471cb28f04b8852ee92e37 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_2e9a90a94bd5e5384d1d06485554f2c8_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_2e9a90a94bd5e5384d1d06485554f2c8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2e9a90a94bd5e5384d1d06485554f2c8 = L.geoJson(null, {
#                 onEachFeature: geo_json_2e9a90a94bd5e5384d1d06485554f2c8_onEachFeature,
#
#                 style: geo_json_2e9a90a94bd5e5384d1d06485554f2c8_styler,
#         });
#
#         function geo_json_2e9a90a94bd5e5384d1d06485554f2c8_add (data) {
#             geo_json_2e9a90a94bd5e5384d1d06485554f2c8
#                 .addData(data);
#         }
#             geo_json_2e9a90a94bd5e5384d1d06485554f2c8_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [159.75, -79.68333], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Meteorite Hills 01255&quot;, &quot;popup&quot;: &quot;Meteorite Hills 01255\u003cbr\u003eType: OC\u003cbr\u003eMass: 6.9g\u003cbr\u003eYear: 2001&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;}}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_2e9a90a94bd5e5384d1d06485554f2c8.bindTooltip(
#                 `&lt;div&gt;
#                      Meteorite Hills 01255
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#         var popup_5fb1857ce7a7c9dcebf3259339900442 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75e84f477c64aec7caec7ad5df2ddade = $(`&lt;div id=&quot;html_75e84f477c64aec7caec7ad5df2ddade&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Meteorite Hills 01255&lt;br&gt;Type: OC&lt;br&gt;Mass: 6.9g&lt;br&gt;Year: 2001&lt;/div&gt;`)[0];
#                 popup_5fb1857ce7a7c9dcebf3259339900442.setContent(html_75e84f477c64aec7caec7ad5df2ddade);
#
#
#
#         geo_json_2e9a90a94bd5e5384d1d06485554f2c8.bindPopup(popup_5fb1857ce7a7c9dcebf3259339900442)
#         ;
#
#
#
#
#             geo_json_2e9a90a94bd5e5384d1d06485554f2c8.addTo(feature_group_72ea3c1c49471cb28f04b8852ee92e37);
#
#
#         function geo_json_7d9384609737ec305e2d18104cab1adf_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_7d9384609737ec305e2d18104cab1adf_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7d9384609737ec305e2d18104cab1adf = L.geoJson(null, {
#                 onEachFeature: geo_json_7d9384609737ec305e2d18104cab1adf_onEachFeature,
#
#                 style: geo_json_7d9384609737ec305e2d18104cab1adf_styler,
#         });
#
#         function geo_json_7d9384609737ec305e2d18104cab1adf_add (data) {
#             geo_json_7d9384609737ec305e2d18104cab1adf
#                 .addData(data);
#         }
#             geo_json_7d9384609737ec305e2d18104cab1adf_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [54.1939, 18.74547], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Dhofar 1078&quot;, &quot;popup&quot;: &quot;Dhofar 1078\u003cbr\u003eType: OC\u003cbr\u003eMass: 72.2g\u003cbr\u003eYear: 2001&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;}}, &quot;type&quot;: &quot;Feature&quot;}], &quot
