# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /opt/conda/lib/python3.8/site-packages (1.33.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/conda/lib/python3.8/site-packages (from streamlit) (6.1)
# Requirement already satisfied: packaging<25,>=16.8 in /opt/conda/lib/python3.8/site-packages (from streamlit) (21.3)
# Requirement already satisfied: pandas<3,>=1.3.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (8.1.2)
# Requirement already satisfied: watchdog>=2.1.5 in /opt/conda/lib/python3.8/site-packages (from streamlit) (4.0.0)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/conda/lib/python3.8/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: protobuf<5,>=3.20 in /opt/conda/lib/python3.8/site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/conda/lib/python3.8/site-packages (from streamlit) (3.1.27)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: pillow<11,>=7.1.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (9.1.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/conda/lib/python3.8/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: altair<6,>=4.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: numpy<2,>=1.19.3 in /opt/conda/lib/python3.8/site-packages (from streamlit) (1.24.4)
# Requirement already satisfied: pyarrow>=7.0 in /opt/conda/lib/python3.8/site-packages (from streamlit) (7.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /opt/conda/lib/python3.8/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (3.1.1)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (4.4.0)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.8/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging<25,>=16.8->streamlit) (3.0.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.8/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2021.10.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (2.0.12)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3,>=2.27->streamlit) (1.26.9)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (3.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.8/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (5.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair<6,>=4.0->streamlit) (3.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
file_path = 'Meteorite_Landings.csv' 
meteorite_data = pd.read_csv(file_path)

# %%
from Modules.drawL import *
from Modules.meteorite_classification import classify_meteorites
meteorite_data['classification_group'] = meteorite_data['recclass'].apply(classify_meteorites) #apply the ouput of the module to the data
create_map_with_input(meteorite_data)
# Out:
# Enter the number of random samples you want to display:  80
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e102abcbc7fe3fdd01f61ad10dcad778 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_div {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e102abcbc7fe3fdd01f61ad10dcad778&quot; &gt;&lt;/div&gt;
#
#     &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_div&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e102abcbc7fe3fdd01f61ad10dcad778 = L.map(
#                 &quot;map_e102abcbc7fe3fdd01f61ad10dcad778&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d9b54a062d8d9b684586c95013347d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0d9b54a062d8d9b684586c95013347d2.addTo(map_e102abcbc7fe3fdd01f61ad10dcad778);
#
#
#             var feature_group_7dd51d16f6219301195555db92fdf6a8 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_75c5f70e4d7bddc272c6c2a333f0a813_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_75c5f70e4d7bddc272c6c2a333f0a813_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_75c5f70e4d7bddc272c6c2a333f0a813 = L.geoJson(null, {
#                 onEachFeature: geo_json_75c5f70e4d7bddc272c6c2a333f0a813_onEachFeature,
#
#                 style: geo_json_75c5f70e4d7bddc272c6c2a333f0a813_styler,
#         });
#
#         function geo_json_75c5f70e4d7bddc272c6c2a333f0a813_add (data) {
#             geo_json_75c5f70e4d7bddc272c6c2a333f0a813
#                 .addData(data);
#         }
#             geo_json_75c5f70e4d7bddc272c6c2a333f0a813_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [75.18944, -73.08972], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Grove Mountains 020007&quot;, &quot;popup&quot;: &quot;Grove Mountains 020007\u003cbr\u003eType: OC\u003cbr\u003eMass: 25.94g\u003cbr\u003eYear: 2002&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;}}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_75c5f70e4d7bddc272c6c2a333f0a813.bindTooltip(
#                 `&lt;div&gt;
#                      Grove Mountains 020007
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#         var popup_08d828458e01c63c24d6cd70f10917f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e46be0ac6668e886aaf6e3979fbc844a = $(`&lt;div id=&quot;html_e46be0ac6668e886aaf6e3979fbc844a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grove Mountains 020007&lt;br&gt;Type: OC&lt;br&gt;Mass: 25.94g&lt;br&gt;Year: 2002&lt;/div&gt;`)[0];
#                 popup_08d828458e01c63c24d6cd70f10917f7.setContent(html_e46be0ac6668e886aaf6e3979fbc844a);
#
#
#
#         geo_json_75c5f70e4
