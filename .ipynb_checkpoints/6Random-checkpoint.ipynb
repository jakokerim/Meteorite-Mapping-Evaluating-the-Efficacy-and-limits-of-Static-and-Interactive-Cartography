# %%
import pandas as pd
file_path = 'Meteorite_Landings.csv' 
meteorite_data = pd.read_csv(file_path)

# %%
from Modules.meteorite_classification import classify_meteorites
meteorite_data['classification_group'] = meteorite_data['recclass'].apply(classify_meteorites)

# %% [markdown]
# # **Random in code**

# %% [markdown]
# This code output is identical to the previous but only add the sample in the function instead of asking the user an input.

# %%
from Modules.random import * 
m = display_map_with_search_bar(meteorite_data, 10)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51b65cf504c77b2f2d7054e94bc1f1c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-search@2.9.7/dist/leaflet-search.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51b65cf504c77b2f2d7054e94bc1f1c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51b65cf504c77b2f2d7054e94bc1f1c7 = L.map(
#                 &quot;map_51b65cf504c77b2f2d7054e94bc1f1c7&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d1af1558a3901ae37649bb4119714db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8d1af1558a3901ae37649bb4119714db.addTo(map_51b65cf504c77b2f2d7054e94bc1f1c7);
#
#
#             var feature_group_7f0ca8c2053bc4d4e4c6d9cf51c9394d = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_cf9b9f244288f182098c82ee1ffe6294_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_cf9b9f244288f182098c82ee1ffe6294_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cf9b9f244288f182098c82ee1ffe6294 = L.geoJson(null, {
#                 onEachFeature: geo_json_cf9b9f244288f182098c82ee1ffe6294_onEachFeature,
#
#                 style: geo_json_cf9b9f244288f182098c82ee1ffe6294_styler,
#         });
#
#         function geo_json_cf9b9f244288f182098c82ee1ffe6294_add (data) {
#             geo_json_cf9b9f244288f182098c82ee1ffe6294
#                 .addData(data);
#         }
#             geo_json_cf9b9f244288f182098c82ee1ffe6294_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [75.31447, -72.77886], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Grove Mountains 090975&quot;, &quot;popup&quot;: &quot;Grove Mountains 090975\u003cbr\u003eType: OC\u003cbr\u003eMass: 57.51g\u003cbr\u003eYear: 2010&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;}}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_cf9b9f244288f182098c82ee1ffe6294.bindTooltip(
#                 `&lt;div&gt;
#                      Grove Mountains 090975
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#         var popup_c1fdaa46e6a38b00347336b03d3f453e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2114632f94378a3a5ad72de7ed3e5b91 = $(`&lt;div id=&quot;html_2114632f94378a3a5ad72de7ed3e5b91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grove Mountains 090975&lt;br&gt;Type: OC&lt;br&gt;Mass: 57.51g&lt;br&gt;Year: 2010&lt;/div&gt;`)[0];
#                 popup_c1fdaa46e6a38b00347336b03d3f453e.setContent(html_2114632f94378a3a5ad72de7ed3e5b91);
#
#
#
#         geo_json_cf9b9f244288f182098c82ee1ffe6294.bindPopup(popup_c1fdaa46e6a38b00347336b03d3f453e)
#         ;
#
#
#
#
#             geo_json_cf9b9f244288f182098c82ee1ffe6294.addTo(feature_group_7f0ca8c2053bc4d4e4c6d9cf51c9394d);
#
#
#         function geo_json_17d4d111f04a631d53716b6469f511d9_styler(feature) {
#             switch(feature.properties.name) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;};
#             }
#         }
#
#         function geo_json_17d4d111f04a631d53716b6469f511d9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_17d4d111f04a631d53716b6469f511d9 = L.geoJson(null, {
#                 onEachFeature: geo_json_17d4d111f04a631d53716b6469f511d9_onEachFeature,
#
#                 style: geo_json_17d4d111f04a631d53716b6469f511d9_styler,
#         });
#
#         function geo_json_17d4d111f04a631d53716b6469f511d9_add (data) {
#             geo_json_17d4d111f04a631d53716b6469f511d9
#                 .addData(data);
#         }
#             geo_json_17d4d111f04a631d53716b6469f511d9_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [35.66667, -71.5], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Yamato 791211&quot;, &quot;popup&quot;: &quot;Yamato 791211\u003cbr\u003eType: OC\u003cbr\u003eMass: 161.67g\u003cbr\u003eYear: 1979&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;}}, &quot;type&quot;: &quot;Feature&
